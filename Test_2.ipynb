# %% [markdown]
# # **Enzyme Mechanics Exam 2**
# *Klenow Fragment Case Study, Nicotinamides, Alcohol Dehydrogenases (ADH), Flavins, Flavin Monooxygenase, Baeyer-Villager Monooxygenase, Pterins, and Cytochrome P-450s*

# %%
from rdkit import Chem
from rdkit.Chem import Draw, Descriptors, AllChem

# %% [markdown]
# ## *Klenow Fragment Case Study*

# %% [markdown]
# *Background Needed*
# The Klenow Fragment is a large fragment of DNA Polymerase-I that retains both the 5'-3' polymerase & 3'-5' exonuclease activity; lacks 5'-3' exonuclease activity. Exonuclease activity is the process of removing nucleotides from the 5' and 3' ends of a RNA/DNA strand via hydrolysis of the phosphodiester bonds.

# %%
mol = Chem.MolFromSmiles('CCO')
Draw.MolToImage(mol)
Draw.MolsToGridImage([mol1, mol2], molsPerRow=2, subImgSize=(300, 300))
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[2], line 2
#       1 mol = Chem.MolFromSmiles('CCO')
# ----> 2 Draw.MolToImage(mol)
#       3 Draw.MolsToGridImage([mol1, mol2], molsPerRow=2, subImgSize=(300, 300))
#
# File /opt/anaconda3/lib/python3.13/site-packages/rdkit/Chem/Draw/__init__.py:103, in MolToImage(mol, size, kekulize, wedgeBonds, fitImage, options, **kwargs)
#     101   raise ValueError('Null molecule provided')
#     102 if not hasattr(rdMolDraw2D, 'MolDraw2DCairo'):
# --> 103   raise RuntimeError("MolToImage requires that the RDKit be built with Cairo support")
#     104 return _moltoimg(mol, size, kwargs.get('highlightAtoms', []), kwargs.get('legend', ''),
#     105                  highlightBonds=kwargs.get('highlightBonds',
#     106                                            []), drawOptions=options, kekulize=kekulize,
# ...
