# %% [markdown]
# # **Enzyme Mechanics Exam 2**
# *Substitutions, terpenes, isomerases, Geranyl Diphosphate Synthase, Farnesyl-DP Synthase, sugar phosphorylases, epoxide hydrolases, carboxylations, Vitamin K, base amplification, and enzymatic/amino acid/pyruvoyl dependent decarboxylations*

# %% [markdown]
# ## ***Substitutions***
#
# There are multiple sub-topics in substitutions and its the least-recent thingy we covered so theres gonna be a bit more content in this section. To begin, (nucleophilic) substitutions are when one group attached to the carbon gets replaced, substituted, with another group. The attacking group is called the nucleophile, while the ejected group is called the leaving group. For nucleophilic subsitions, there are 3 primary 'players' we must consider:
# - the nucleophile (attacking group)
# - the electrophile (point of reaction)
# - the leaving group (ejected group)
#
# There are generally 2 types of substitution reactions, S<sub>n</sub>1 & S<sub>n</sub>2 reactions. S<sub>n</sub>1 reactions are stepwise and unimolecular (2 step). The LG (leaving group) departs first, generating a discrete carbocation intermediate, only then does the nucleophile come in and attack the electrophilic region; the starting stereochemistry is conserved.
#
# S<sub>n</sub>2 reactions are concerted and bimolecular (1 step). The LG gets ejected by the simultaneous backside attack of the nucleophile. The nucleophile is forced to attack the electrophile on the opposite (back) side of the LG causing the stereochemistry to invert.
#
# For the following enzymes, we should ask the following questions:
# 1. What is the electrophile and why is it electrophilic?
# 2. What is the LG and how is the substrate stabilized after it's ejection?
# 3. What is the nucleophile and how does the enzyme position/activate it?
# 4. Is this an S<sub>n</sub>1 or S<sub>n</sub>2 reaction and what evidence do we have to support this?
#
# ### *Terpenes*
#
# There are 3 terpenes centered substituion enzymes/reactions that we need to cover:
# - IPP Isomerase
# - Geranyl Diphosphate Synthase
# - Farnesyl-DP Synthase
#
# IPP Isomerase is by far the simplest, setting the template for how we should expect these reactions to go down: **Ionization of an allylic diphosphate to generate a carbocation, followed by nucleophilic capture by an alkene π bond**. Isopentyl Diphosphate (IPP) is initially generated by 2 acetyl-CoA molecules reacting together with CO<sub>2</sub> as a byproduct. IPP then undergoes isomerization where a singular protanted base group, protonates (lock in bro) the alkene of IPP forming a tertiary carbocation intermediate. The secondary α-carbon of the carbocation then gets deprotonated by the base group, creating an alkene between the secondary and tertiary carbon; product is Dimethyl Diphosphate (Di-PP). It's a simple 2 step reaction (S<sub>n</sub>1) and it's the basis for how the following reactions will go down
#
# Geranyl Diphosphate Synthase (GDS) might seem daunting at first but this too is a pretty simple polymerization reaction. Geranyl diphosphate is a steroid precursor so it was once a high interest enzyme. What's unique about GDS is that it uses a Mg<sup>2+</sup> ligand to stabilize the negative charges on the diphosphate; the polymerization wouldn't be able to proceed otherwise. The mechanism is identical to IPP Isomerase except the base used *is* isopentyl diphosphate. The reactions essentially works with 1 mole Di-PP reacting with 1 mole IPP, with the diphosphate of the Di-PP acting as an LG (-PP<sub>i</sub>). The exit of PP creates a carbocation on the terminal primary carbon, which then reacts with the IPP. The IPP molecule then forms a carbocation on the tertiary carbon (as we previously saw) and the secondary carbon gets deprotanted by the PP<sub>i</sub> group, reforming the alkene and finishing the Geranyl Disphosphate synthesis. The Farnesyl-DP Synthase proceeds in the same way, except the substrate is Geranyl-DP instead of Di-PP.
#
# All this information is fantastic, but *how do we prove this*? The primary characteristic of the reactions that we should be looking for is the existance of a carbocation, the problem is F-DP Synthase is hyper selective and we're unfortunately not able to make many changes to the substrate or enzyme to analyze it. Researchers found that because flourine is fairly similar to hydrogen in size (high electronegativity -> compacts outer orbitals reducing size), they can insert it into the substrate to replace certain protons to probe the prescence of a carbocation. If the mechanism proceeded via a carbocation, the prescence of a adjacent fluorine would decrease k<sub>cat</sub> by destabilizing the carbocation. A radical or anion mechanism would not be impacted. After the running the reactions with the modified substrates, they did find that fluorine impacted the k<sub>cat</sub>, thus proving the Farnesyl-DP proceeded via a carbocation intermediate.
# ***
#
# ### *Sugar Phosphorylase*
#
# Sugar phosphorylases are enzymes that "shockingly" catalyze the addition of P<sub>i</sub> to sugars. What's pretty cool about sugar phosphorylases is that depending on the end products stereochemistry, you can (typically) quickly determine the mechanism. If sterochemistry is retained:
# - likely 2 S<sub>n</sub>2 reactions
# - first step uses an active-site nucleophile (covalent intermediate)
# - second step uses phosphate to attack anomeric carbon (dissembling enzyme intermediate)
#
# If stereochemistry is inverted:
# - likely a single S<sub>n</sub>2 reaction
# - phosphate attacks the anomeric carbon directly (no intermediate)
#
# The enzyme (almost) always generates a new sugar-1-phosphate product, so the remembering the general rules above you can pretty reliably determine the mechanism in a short amount of time. In class we covered sucrose phosphorylase and tried to determine the mechanism for it. The first thing that reserachers determined was the the phosphorylated product retained it's stereochemistry, telling us it is highly likely the mechanism has 2 S<sub>n</sub>2 reactions with a covalent intermediate. When they ran sucrose + <sup>14</sup>C-fructose + Enz they found that they got a product of <sup>14</sup>C-Sucrose, meaning the initial breaking of the glycoside bond is done by the enzyme, fructose can re-introduce itself post-intermediate formation, and P<sub>i</sub> does not attack the anomeric carbon first. To confirm the enzyme attacks first and isolate the intermediate, they ran <sup>14</sup>C-sucrose + Enz -denature-> -gel filtration->  <sup>14</sup>C-glucose - Enz (intermediate; gel filtration isolates the glucose-enz intermediate and removes the fructose byproduct). They then exposed the intermediate to acidic, neutral, and basic conditions and found that in every condition the end product is <sup>14</sup>C-glucose + Enz. This means ***SPEAK TO DR. STEWART FOR FURTHER EXPLAINATION***
# ***
#
# ### Glycosides
#
# Glycosides are incredibly similar to sugar phosphorylases. I literally have 33% of a page dedicated to them because they're pretty cut and dry; they share the same mechanistic framework as sugar phosphorylases. Main difference is that the incoming nucleophile is a water molecule. One unique thing regarding glycosides is that the reactivity of the glycoside changes depending on whether or not its in an α or β configuration; α-glycosides are more reactive because of better orbital overlap.
# ***
#
# ### Epoxide Hydrolases
#
# ***EASY I WILL FILL IN TOMORROW***

# %% [markdown]
# ## ***Carboxylations***
#
# Carboxylations in its simplest form is the formation of a new C-C bond by adding CO<sub>2</sub> onto a substrate, forming a new carboxyl group. A problem unique to carboxylases is that CO<sub>2</sub> is electrophilic and would require there to be a nucleophilic substrate. This is typically resolved by the presence of an enolization or metal-stabilized carboanions/enolates. Another problem with carboxylases is that the CO<sub>2</sub> must be activated or delivered - free Co<sub>2</sub> in solution is not a great electrophile on it's own (thermodynamically uphill). Some carboxylases use biotin (biotin-dependent) to skirt around this problem, some **[INSERT METHOD THAT DOESNT USE BIOTIN I GUESS]** instead. In this section of the course we only convered PEP carboxylase & Vitamin K so nothing too crazy (I say before trying to describe the Vitamin K mechanism with words).
